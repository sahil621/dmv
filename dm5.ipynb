# %%
import pandas as pd

df = pd.read_csv('5_Data.csv', encoding="cp1252")
df
# Out:
# /var/folders/gn/knphgtjj3ql0kctsghmn_vx00000gn/T/ipykernel_61217/1808999086.py:3: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('5_Data.csv', encoding="cp1252")
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 435737  West Bengal State Pollution Control Board
# 435738  West Bengal State Pollution Control Board
# 435739                                        NaN
# 435740                                        NaN
# 435741                                        NaN
#
#                                       type   so2   no2   rspm  spm  \
# 0       Residential, Rural and other Areas   4.8  17.4    NaN  NaN
# 1                          Industrial Area   3.1   7.0    NaN  NaN
# 2       Residential, Rural and other Areas   6.2  28.5    NaN  NaN
# 3       Residential, Rural and other Areas   6.3  14.7    NaN  NaN
# 4                          Industrial Area   4.7   7.5    NaN  NaN
# ...                                    ...   ...   ...    ...  ...
# 435737                               RIRUO  22.0  50.0  143.0  NaN
# 435738                               RIRUO  20.0  46.0  171.0  NaN
# 435739                                 NaN   NaN   NaN    NaN  NaN
# 435740                                 NaN   NaN   NaN    NaN  NaN
# 435741                                 NaN   NaN   NaN    NaN  NaN
#
#               location_monitoring_station  pm2_5        date
# 0                                     NaN    NaN  1990-02-01
# 1                                     NaN    NaN  1990-02-01
# 2                                     NaN    NaN  1990-02-01
# 3                                     NaN    NaN  1990-03-01
# 4                                     NaN    NaN  1990-03-01
# ...                                   ...    ...         ...
# 435737  Inside Rampal Industries,ULUBERIA    NaN  2015-12-24
# 435738  Inside Rampal Industries,ULUBERIA    NaN  2015-12-29
# 435739                                NaN    NaN         NaN
# 435740                                NaN    NaN         NaN
# 435741                                NaN    NaN         NaN
#
# [435742 rows x 13 columns]

# %%
df['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Dadra & Nagar Haveli',
#        'Daman & Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Uttar Pradesh',
#        'Uttarakhand', 'Uttaranchal', 'West Bengal',
#        'andaman-and-nicobar-islands', 'Lakshadweep', 'Tripura'],
#       dtype=object)

# %%
df['state'] = df['state'].replace({'Uttaranchal' : 'Uttarakhand'})

# %%
df['state'].unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Dadra & Nagar Haveli',
#        'Daman & Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal', 'andaman-and-nicobar-islands',
#        'Lakshadweep', 'Tripura'], dtype=object)

# %%
df['type'].unique()
# Out:
# array(['Residential, Rural and other Areas', 'Industrial Area', nan,
#        'Sensitive Area', 'Industrial Areas', 'Residential and others',
#        'Sensitive Areas', 'Industrial', 'Residential', 'RIRUO',
#        'Sensitive'], dtype=object)

# %%
import numpy as np
types = {
    "Residential": "R",
    "Rural and other Areas" : "RO",
    "Residential and others" : "RO",
    "Industrial" : "I",
    "Industrial Area": "I",
    "Industrial Areas" : "I",
    "Sensitive Area" : "S",
    "Sensitive Areas" : "S",
    "Sensitive" : "S",
    np.nan: "RRO"
}

# %%
df['type'] = df['type'].replace(types)
df['type'].unique()
# Out:
# array(['Residential, Rural and other Areas', 'I', 'RRO', 'S', 'RO', 'R',
#        'RIRUO'], dtype=object)

# %%
df.isna().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                                0
# so2                             34646
# no2                             16233
# rspm                            40222
# spm                            237387
# location_monitoring_station     27491
# pm2_5                          426428
# date                                7
# dtype: int64

# %%
cols = ['so2', 'no2', 'rspm', 'spm', 'pm2_5']

from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")

df[cols] = imputer.fit_transform(df[cols])

df.isna().sum()
# Out:
# stn_code                       144077
# sampling_date                       3
# state                               0
# location                            3
# agency                         149481
# type                                0
# so2                                 0
# no2                                 0
# rspm                                0
# spm                                 0
# location_monitoring_station     27491
# pm2_5                               0
# date                                7
# dtype: int64

# %%
df
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 435737  West Bengal State Pollution Control Board
# 435738  West Bengal State Pollution Control Board
# 435739                                        NaN
# 435740                                        NaN
# 435741                                        NaN
#
#                                       type        so2        no2        rspm  \
# 0       Residential, Rural and other Areas   4.800000  17.400000  108.832784
# 1                                        I   3.100000   7.000000  108.832784
# 2       Residential, Rural and other Areas   6.200000  28.500000  108.832784
# 3       Residential, Rural and other Areas   6.300000  14.700000  108.832784
# 4                                        I   4.700000   7.500000  108.832784
# ...                                    ...        ...        ...         ...
# 435737                               RIRUO  22.000000  50.000000  143.000000
# 435738                               RIRUO  20.000000  46.000000  171.000000
# 435739                                 RRO  10.829414  25.809623  108.832784
# 435740                                 RRO  10.829414  25.809623  108.832784
# 435741                                 RRO  10.829414  25.809623  108.832784
#
#               spm        location_monitoring_station      pm2_5        date
# 0       220.78348                                NaN  40.791467  1990-02-01
# 1       220.78348                                NaN  40.791467  1990-02-01
# 2       220.78348                                NaN  40.791467  1990-02-01
# 3       220.78348                                NaN  40.791467  1990-03-01
# 4       220.78348                                NaN  40.791467  1990-03-01
# ...           ...                                ...        ...         ...
# 435737  220.78348  Inside Rampal Industries,ULUBERIA  40.791467  2015-12-24
# 435738  220.78348  Inside Rampal Industries,ULUBERIA  40.791467  2015-12-29
# 435739  220.78348                                NaN  40.791467         NaN
# 435740  220.78348                                NaN  40.791467         NaN
# 435741  220.78348                                NaN  40.791467         NaN
#
# [435742 rows x 13 columns]

# %%
each_state_so2 = df.groupby('state')['so2'].mean()

# %%
each_state_so2
# Out:
# state
# Andhra Pradesh                  7.377196
# Arunachal Pradesh               5.134184
# Assam                           6.751470
# Bihar                          18.825122
# Chandigarh                      6.601060
# Chhattisgarh                   12.717299
# Dadra & Nagar Haveli            8.954491
# Daman & Diu                     8.196329
# Delhi                           8.918570
# Goa                             7.514603
# Gujarat                        16.631424
# Haryana                        13.799113
# Himachal Pradesh                4.914026
# Jammu & Kashmir                 7.239967
# Jharkhand                      23.235550
# Karnataka                      10.257348
# Kerala                          5.842145
# Lakshadweep                    10.829414
# Madhya Pradesh                 11.485316
# Maharashtra                    17.143621
# Manipur                         8.550002
# Meghalaya                       9.203893
# Mizoram                         3.695303
# Nagaland                        5.160991
# Odisha                          6.199112
# Puducherry                     11.912748
# Punjab                         10.636675
# Rajasthan                       7.699848
# Sikkim                         19.800000
# Tamil Nadu                     11.298839
# Telangana                       5.460775
# Tripura                        10.829414
# Uttar Pradesh                  12.428220
# Uttarakhand                    19.225415
# West Bengal                    12.517750
# andaman-and-nicobar-islands    10.829414
# Name: so2, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(each_state_so2.index, each_state_so2)
plt.xticks(rotation=90)
plt.show()

# %%
data = each_state_so2.sort_values(ascending=False)

# %%
top_10 = data[:10]
bottom_10 = data[-10:]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(top_10.index, top_10)
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.bar(bottom_10.index, bottom_10)
plt.xticks(rotation=90)
plt.show()

# %%
df
# Out:
#        stn_code       sampling_date                        state   location  \
# 0         150.0  February - M021990               Andhra Pradesh  Hyderabad
# 1         151.0  February - M021990               Andhra Pradesh  Hyderabad
# 2         152.0  February - M021990               Andhra Pradesh  Hyderabad
# 3         150.0     March - M031990               Andhra Pradesh  Hyderabad
# 4         151.0     March - M031990               Andhra Pradesh  Hyderabad
# ...         ...                 ...                          ...        ...
# 435737     SAMP            24-12-15                  West Bengal   ULUBERIA
# 435738     SAMP            29-12-15                  West Bengal   ULUBERIA
# 435739      NaN                 NaN  andaman-and-nicobar-islands        NaN
# 435740      NaN                 NaN                  Lakshadweep        NaN
# 435741      NaN                 NaN                      Tripura        NaN
#
#                                            agency  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 435737  West Bengal State Pollution Control Board
# 435738  West Bengal State Pollution Control Board
# 435739                                        NaN
# 435740                                        NaN
# 435741                                        NaN
#
#                                       type        so2        no2        rspm  \
# 0       Residential, Rural and other Areas   4.800000  17.400000  108.832784
# 1                                        I   3.100000   7.000000  108.832784
# 2       Residential, Rural and other Areas   6.200000  28.500000  108.832784
# 3       Residential, Rural and other Areas   6.300000  14.700000  108.832784
# 4                                        I   4.700000   7.500000  108.832784
# ...                                    ...        ...        ...         ...
# 435737                               RIRUO  22.000000  50.000000  143.000000
# 435738                               RIRUO  20.000000  46.000000  171.000000
# 435739                                 RRO  10.829414  25.809623  108.832784
# 435740                                 RRO  10.829414  25.809623  108.832784
# 435741                                 RRO  10.829414  25.809623  108.832784
#
#               spm        location_monitoring_station      pm2_5        date
# 0       220.78348                                NaN  40.791467  1990-02-01
# 1       220.78348                                NaN  40.791467  1990-02-01
# 2       220.78348                                NaN  40.791467  1990-02-01
# 3       220.78348                                NaN  40.791467  1990-03-01
# 4       220.78348                                NaN  40.791467  1990-03-01
# ...           ...                                ...        ...         ...
# 435737  220.78348  Inside Rampal Industries,ULUBERIA  40.791467  2015-12-24
# 435738  220.78348  Inside Rampal Industries,ULUBERIA  40.791467  2015-12-29
# 435739  220.78348                                NaN  40.791467         NaN
# 435740  220.78348                                NaN  40.791467         NaN
# 435741  220.78348                                NaN  40.791467         NaN
#
# [435742 rows x 13 columns]

# %%
pivot = df.pivot_table(index="type", values=["so2", "no2", "rspm", "spm", "pm2_5"], aggfunc="mean")

# %%
pivot
# Out:
#                                           no2      pm2_5        rspm  \
# type
# I                                   29.325791  40.850110  120.624388
# R                                   21.331916  40.791467  108.832784
# RIRUO                               31.779908  39.474997  103.617331
# RO                                  25.413627  40.791467  102.981682
# RRO                                 27.512628  40.791467  104.776528
# Residential, Rural and other Areas  23.471539  40.752550  102.812524
# S                                   20.214671  40.791467  100.053598
#
#                                           so2         spm
# type
# I                                   13.225617  230.830214
# R                                   13.835891  272.668993
# RIRUO                               10.912577  220.783480
# RO                                  10.353020  214.538753
# RRO                                 16.005595  187.528211
# Residential, Rural and other Areas   9.272324  215.931679
# S                                    6.617897  227.048483

# %%
pivot.plot(kind="bar")
# Out:
# <Axes: xlabel='type'>
